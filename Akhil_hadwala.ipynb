# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\akhil\Downloads\dataset.csv")

# %%
df
# Out:
#       user_id  session_id           profession           tool  \
# 0       43140        3817   Software Developer        ChatGPT
# 1        9263       89304            Architect  Perplexity AI
# 2       33655      113595           HR Manager   Grammarly AI
# 3       11705      155151           Accountant         Claude
# 4        4384        4358            Scientist         Gemini
# ...       ...         ...                  ...            ...
# 4995    17144       22133              Student      Cursor AI
# 4996    49443       64573            Professor      Cursor AI
# 4997     3097      198064  Mechanical Engineer     Midjourney
# 4998    42128      170752           HR Manager         DALL-E
# 4999     4210      181799             YouTuber        AutoGPT
#
#               use_case  iterations prompt_complexity  quality_with_ai  \
# 0         Blog Writing           5               low             10.0
# 1        Medical Notes           4            medium              8.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                5000 non-null   int64
#  1   session_id             5000 non-null   int64
#  2   profession             5000 non-null   object
#  3   tool                   5000 non-null   object
#  4   use_case               5000 non-null   object
#  5   iterations             5000 non-null   int64
#  6   prompt_complexity      5000 non-null   object
#  7   quality_with_ai        5000 non-null   float64
#  8   quality_without_ai     5000 non-null   float64
#  9   productivity_gain      5000 non-null   float64
#  10  final_quality_label    5000 non-null   object
#  11  confidence_with_ai     5000 non-null   int64
#  12  confidence_without_ai  5000 non-null   int64
#  13  overreliance_score     5000 non-null   float64
# ...

# %%
df.describe()
# Out:
#            user_id     session_id   iterations  quality_with_ai  \
# count   5000.00000    5000.000000  5000.000000      5000.000000
# mean   24790.77600  101821.548800     3.522200         7.845500
# std    14401.10469   58055.889587     1.728035         0.945811
# min       28.00000      41.000000     1.000000         6.500000
# 25%    12495.75000   52281.250000     2.000000         7.000000
# 50%    24699.50000  102303.000000     4.000000         8.000000
# 75%    37280.00000  153499.750000     5.000000         8.500000
# max    49997.00000  199928.000000     6.000000        10.000000
#
#        quality_without_ai  productivity_gain  confidence_with_ai  \
# count         5000.000000        5000.000000         5000.000000
# mean             4.990965          28.545364            7.336000
# std              1.147355          14.869652            1.137437
# min              3.002290          -4.940000            5.000000
# ...

# %%
df.head()
# Out:
#    user_id  session_id          profession           tool          use_case  \
# 0    43140        3817  Software Developer        ChatGPT      Blog Writing
# 1     9263       89304           Architect  Perplexity AI     Medical Notes
# 2    33655      113595          HR Manager   Grammarly AI  Image Generation
# 3    11705      155151          Accountant         Claude    Marketing Copy
# 4     4384        4358           Scientist         Gemini    Marketing Copy
#
#    iterations prompt_complexity  quality_with_ai  quality_without_ai  \
# 0           5               low             10.0            4.139299
# 1           4            medium              8.0            6.379619
# 2           6               low              9.0            6.240725
# 3           3            medium              7.5            6.113465
# 4           2            medium              7.0            5.221701
#
#    productivity_gain  ... overreliance_score  learning_loss  \
# ...

# %%
df= df.drop(columns=['user_id','session_id'])

# %%
num_cols = df.select_dtypes(include=['int','float']).columns
num_cols
# Out:
# Index(['iterations', 'quality_with_ai', 'quality_without_ai',
#        'productivity_gain', 'confidence_with_ai', 'confidence_without_ai',
#        'overreliance_score', 'learning_loss', 'hallucination_flag',
#        'ease_of_use', 'requires_login', 'session_length'],
#       dtype='object')

# %%
cat_cols = df.select_dtypes(exclude=['int','float']).columns
cat_cols
# Out:
# Index(['profession', 'tool', 'use_case', 'prompt_complexity',
#        'final_quality_label', 'failure_type', 'ui_complexity',
#        'subscription_type', 'deadline_pressure'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   profession             5000 non-null   object
#  1   tool                   5000 non-null   object
#  2   use_case               5000 non-null   object
#  3   iterations             5000 non-null   int64
#  4   prompt_complexity      5000 non-null   object
#  5   quality_with_ai        5000 non-null   float64
#  6   quality_without_ai     5000 non-null   float64
#  7   productivity_gain      5000 non-null   float64
#  8   final_quality_label    5000 non-null   object
#  9   confidence_with_ai     5000 non-null   int64
#  10  confidence_without_ai  5000 non-null   int64
#  11  overreliance_score     5000 non-null   float64
#  12  learning_loss          5000 non-null   int64
#  13  hallucination_flag     5000 non-null   int64
# ...

# %%
for i in num_cols:
    print(i,df[i].nunique())
# Out:
# iterations 6
# quality_with_ai 8
# quality_without_ai 5000
# productivity_gain 3294
# confidence_with_ai 6
# confidence_without_ai 8
# overreliance_score 601
# learning_loss 2
# hallucination_flag 2
# ease_of_use 6
# requires_login 2
# session_length 56

# %%
for i in cat_cols:
    print(i,df[i].nunique())
# Out:
# profession 31
# tool 16
# use_case 18
# prompt_complexity 3
# final_quality_label 2
# failure_type 4
# ui_complexity 3
# subscription_type 3
# deadline_pressure 3

# %%
df = df.drop(columns=['quality_without_ai','profession','tool','use_case','overreliance_score','session_length','failure_type'])

# %%
df.describe()
# Out:
#         iterations  quality_with_ai  productivity_gain  confidence_with_ai  \
# count  5000.000000      5000.000000        5000.000000         5000.000000
# mean      3.522200         7.845500          28.545364            7.336000
# std       1.728035         0.945811          14.869652            1.137437
# min       1.000000         6.500000          -4.940000            5.000000
# 25%       2.000000         7.000000          17.840000            6.750000
# 50%       4.000000         8.000000          28.570000            7.000000
# 75%       5.000000         8.500000          39.192500            8.000000
# max       6.000000        10.000000          69.970000           10.000000
#
#        confidence_without_ai  learning_loss  hallucination_flag  ease_of_use  \
# count            5000.000000     5000.00000         5000.000000    5000.0000
# mean                4.506600        0.50040            0.294200       7.5296
# ...

# %%
df.isnull().sum()
# Out:
# iterations               0
# prompt_complexity        0
# quality_with_ai          0
# productivity_gain        0
# final_quality_label      0
# confidence_with_ai       0
# confidence_without_ai    0
# learning_loss            0
# hallucination_flag       0
# ease_of_use              0
# ui_complexity            0
# requires_login           0
# subscription_type        0
# deadline_pressure        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x = df.drop(columns=['productivity_gain'])
x
# Out:
#       iterations prompt_complexity  quality_with_ai final_quality_label  \
# 0              5               low             10.0                high
# 1              4            medium              8.0                high
# 2              6               low              9.0                high
# 3              3            medium              7.5              medium
# 4              2            medium              7.0              medium
# ...          ...               ...              ...                 ...
# 4995           4              high              8.0                high
# 4996           2              high              7.0              medium
# 4997           1              high              6.5              medium
# 4998           3            medium              7.5              medium
# 4999           1            medium              6.5              medium
#
#       confidence_with_ai  confidence_without_ai  learning_loss  \
# ...

# %%
y = df['productivity_gain']
y
# Out:
# 0       58.61
# 1       16.20
# 2       27.59
# 3       13.87
# 4       17.78
#         ...
# 4995    16.77
# 4996    31.40
# 4997    18.32
# 4998    20.52
# 4999     5.52
# Name: productivity_gain, Length: 5000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((4000, 13), (4000,), (1000, 13), (1000,))

# %%
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,MinMaxScaler

# %%
x
# Out:
#       iterations prompt_complexity  quality_with_ai final_quality_label  \
# 0              5               low             10.0                high
# 1              4            medium              8.0                high
# 2              6               low              9.0                high
# 3              3            medium              7.5              medium
# 4              2            medium              7.0              medium
# ...          ...               ...              ...                 ...
# 4995           4              high              8.0                high
# 4996           2              high              7.0              medium
# 4997           1              high              6.5              medium
# 4998           3            medium              7.5              medium
# 4999           1            medium              6.5              medium
#
#       confidence_with_ai  confidence_without_ai  learning_loss  \
# ...

# %%
for i in x:
    print(i,x[i].unique())
# Out:
# iterations [5 4 6 3 2 1]
# prompt_complexity ['low' 'medium' 'high']
# quality_with_ai [10.   8.   9.   7.5  7.   6.5  8.5  9.5]
# final_quality_label ['high' 'medium']
# confidence_with_ai [10  7  8  6  9  5]
# confidence_without_ai [4 5 7 6 2 3 8 1]
# learning_loss [1 0]
# hallucination_flag [0 1]
# ease_of_use [ 9  5  7 10  8  6]
# ui_complexity ['low' 'medium' 'high']
# requires_login [1 0]
# subscription_type ['freemium' 'paid' 'free']
# deadline_pressure ['low' 'medium' 'high']

# %%
# cols_for_ohe
order_for_oe = ['low','medium','high']

ohe= OneHotEncoder()
ohe

oe = OrdinalEncoder(categories=order_for_oe)
oe

min_max = MinMaxScaler()
min_max
# Out:
# MinMaxScaler()

# %%
cols_ohe = ['subscription_type']
cols_oe = ['prompt_complexity','final_quality_label','ui_complexity','deadline_pressure']
cols_min_max =['iterations','quality_with_ai','confidence_with_ai','confidence_without_ai','learning_loss','hallucination_flag','ease_of_use','requires_login']

# %%
from sklearn.compose import ColumnTransformer

# %%
ct1 = ColumnTransformer(transformers=[('ordinal',OrdinalEncoder(),cols_oe),
                                     ('onehot',OneHotEncoder(),cols_ohe),
                                     ('minmax',MinMaxScaler(),cols_min_max)])
